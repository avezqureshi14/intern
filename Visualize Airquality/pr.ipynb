# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\LAB\DSBDA\Visualize Airquality\AirQualityUCI.csv")

# %%
#Histogram
plt.figure(figsize=(8,6))
plt.hist(df['CO(GT)'],bins=10,edgecolor='black')
plt.xlabel('CO(GT)')
plt.ylabel('Frequency')
plt.title('Histogram of CO(GT)')
plt.show()

# %%
#Boxplot
plt.figure(figsize=(8,6))
sns.boxplot(data=df[['CO(GT)','NO2(GT)','Ozone']])
plt.title('Boxplot of CO(GT), NO2(GT),Ozone')
plt.show()

# %%
#Sccatter plot
plt.figure(figsize=(8,6))
sns.scatterplot(data=df,x='Temp',y='RH')
plt.title('Scatter plot of Temp vs RH')
plt.show()

# %%
#heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True,square=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\avezq\AppData\Local\Temp\ipykernel_23728\140222792.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,square=True,cmap='coolwarm')
